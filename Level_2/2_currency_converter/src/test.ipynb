# %% [markdown]
# # Google Books API

# %%
import requests

# Define a function to get exchange rates
def get_exchange_rate(base_currency, target_currency):
    url = f'https://api.exchangerate-api.com/v4/latest/{base_currency}'
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return data['rates'][target_currency.upper()]
    elif response.status_code == 404:
        print("Error 404: The requested resource was not found.")
    elif response.status_code == 500:
        print("Error 500: Internal server error. Please try again later.")
    else:
        print(f"Error: Received unexpected status code {response.status_code}.")

# Define a function that converts the currency
def currency_converter(base_amount, base_currency, target_currency):
    rate = get_exchange_rate(base_currency, target_currency)
    return base_amount * rate

# %%
currency_converter(100, 'usd', 'irr')
# Out:
# 4201707.0

# %%
# Out:
# {'kind': 'books#volumes', 'totalItems': 1000000, 'items': [{'kind': 'books#volume', 'id': 'aJQILlLxRmAC', 'etag': 'JRAPjBtntDc', 'selfLink': 'https://www.googleapis.com/books/v1/volumes/aJQILlLxRmAC', 'volumeInfo': {'title': 'Python Programming', 'subtitle': 'An Introduction to Computer Science', 'authors': ['John M. Zelle'], 'publisher': 'Franklin, Beedle & Associates, Inc.', 'publishedDate': '2004', 'description': 'This book is suitable for use in a university-level first course in computing (CS1), as well as the increasingly popular course known as CS0. It is difficult for many students to master basic concepts in computer science and programming. A large portion of the confusion can be blamed on the complexity of the tools and materials that are traditionally used to teach CS1 and CS2. This textbook was written with a single overarching goal: to present the core concepts of computer science as simply as possible without being simplistic.', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781887902991'}, {'type': 'ISBN_10', 'identifier': '1887902996'}], 'readingModes': {'text': False, 'image': True}, 'pageCount': 533, 'printType': 'BOOK', 'categories': ['Computers'], 'averageRating': 4, 'ratingsCount': 18, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': '1.2.2.0.preview.1', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=aJQILlLxRmAC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=aJQILlLxRmAC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.ca/books?id=aJQILlLxRmAC&printsec=frontcover&dq=python+programming&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.ca/books?id=aJQILlLxRmAC&dq=python+programming&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/Python_Programming.html?hl=&id=aJQILlLxRmAC'}, 'saleInfo': {'country': 'CA', 'saleability': 'NOT_FOR_SALE', 'isEbook': False}, 'accessInfo': {'country': 'CA', 'viewability': 'PARTIAL', 'embeddable': True, 'publicDomain': False, 'textToSpeechPermission': 'ALLOWED', 'epub': {'isAvailable': False}, 'pdf': {'isAvailable': True, 'acsTokenLink': 'http://books.google.ca/books/download/Python_Programming-sample-pdf.acsm?id=aJQILlLxRmAC&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'}, 'webReaderLink': 'http://play.google.com/books/reader?id=aJQILlLxRmAC&hl=&source=gbs_api', 'accessViewStatus': 'SAMPLE', 'quoteSharingAllowed': False}, 'searchInfo': {'textSnippet': 'This book is suitable for use in a university-level first course in computing (CS1), as well as the increasingly popular course known as CS0.'}}, {'kind': 'books#volume', 'id': 'T5bRDAAAQBAJ', 'etag': 'KuOnfolOmcE', 'selfLink': 'https://www.googleapis.com/books/v1/volumes/T5bRDAAAQBAJ', 'volumeInfo': {'title': 'Introduction to Computation and Programming Using Python, second edition', 'subtitle': 'With Application to Understanding Data', 'authors': ['John V. Guttag'], 'publisher': 'MIT Press', 'publishedDate': '2016-08-08', 'description': "The new edition of an introductory text that teaches students the art of computational problem solving, covering topics ranging from simple algorithms to information visualization. This book introduces students with little or no prior programming experience to the art of computational problem solving using Python and various Python libraries, including PyLab. It provides students with skills that will enable them to make productive use of computational techniques, including some of the tools and techniques of data science for using computation to model and interpret data. The book is based on an MIT course (which became the most popular course offered through MIT's OpenCourseWare) and was developed for use not only in a conventional classroom bu ...

# %% [markdown]
# # Giphy API

# %%
import os

params = {
    "api_key": os.environ["GIPHY_API_KEY"],
    "q": "football"
}
url = "https://api.giphy.com/v1/gifs/search"
response = requests.get(url, params=params)

# %%
# CHeck status code
if response.status_code == 200:
    data = response.json()
    for gif in data['data']:
        print (gif['title'])
        print (gif['images']['original']['url'])
        print('************')
# Out:
# Season 2 Football GIF by The Office
# https://media0.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/C0D9AFGOus9TIRA6CF/giphy.gif
# ************
# Fail College Football GIF by Clemson Tigers
# https://media1.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/lAZ6fhepvAUec/giphy.gif
# ************
# Excited Episode 12 GIF by The Simpsons
# https://media4.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/3orieWABCODOOw4x7G/giphy.gif
# ************
# Fail Charlie Brown GIF by Peanuts
# https://media4.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/fsnzYr1pgvAQM/giphy.gif
# ************
# Football Sport GIF by FC Bayern Munich
# https://media4.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/OJNYUlH3IBtcKdwV6r/giphy.gif
# ************
# Football Fail GIF by America's Funniest Home Videos
# https://media3.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/l41m2CdrZUCtgtXWg/giphy.gif
# ************
# Football Snl GIF by Saturday Night Live
# https://media3.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/Lj7UuAexAj8fAQIrQT/giphy.gif
# ************
# Team Ncaa GIF by Texas State Football
# https://media3.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/KkQAJiBpp7Qwly9u5t/giphy.gif
# ************
# Alvin Kamara Mic Drop GIF by New Orleans Saints
# https://media2.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/m9wAfs1N0xdQuvgAzR/giphy.gif
# ************
# Nfl Now Football GIF by Sylvia Boomer Yang
# https://media0.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/3o85xmveqgyGLtp4OI/giphy.gif
# ************
# Lets Go Football GIF by Pudgy Penguins
# https://media2.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/7pYfWpN2TXpcxYRcf2/giphy.gif
# ************
# Football Superbowl GIF by Trey Songz
# https://media1.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/l3q2xlD5RqCD97PpK/giphy.gif
# ************
# Field Goal Football GIF by TUMS
# https://media0.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/daDUH19cIzlnU3UXP2/giphy.gif
# ************
# Football Fast Motion GIF by Saweetie
# https://media3.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/TWbYCYLV60Q9VW7WoE/giphy.gif
# ************
# Gordon Ramsay Football GIF by First We Feast
# https://media0.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/92j7nXnSLS36TgLO2u/giphy.gif
# ************
# Super Bowl Win GIF by PLAYMOBIL
# https://media0.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/93waEHlajOcnN4zHo8/giphy.gif
# ************
# Super Bowl Win GIF by PLAYMOBIL
# https://media3.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/EzJkhslhYAEpNumRyK/giphy.gif
# ************
# Mean Girls Football GIF by Paramount Movies
# https://media3.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/SKzwAKuI1Ng8JzZgYf/giphy.gif
# ************
# College Football Running GIF by Boomerang Official
# https://media4.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/9PkdmS9Rc4Xay773QY/giphy.gif
# ************
# Football Art GIF by UnusualCooking
# https://media0.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/VkEXQ9ETuP4RgsPX8z/giphy.gif
# ************
# Football Running GIF by Crispe
# https://media3.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/ElrAN7T2acExy/giphy.gif
# ************
# College Football Win GIF by Boomerang Official
# https://media0.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/ORUsy5ZwwqZsd5jyd8/giphy.gif
# ************
# Excited World Cup GIF by FIFA
# https://media4.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/0ELCFzlkve2qGBnkXW/giphy.gif
# ************
# Football Baby GIF by The Dude Perfect Show
# https://media4.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/3o6ozhCgfTQqsKkIJG/giphy.gif
# ************
# Whats Happening Hello GIF by Liverpool FC
# https://media4.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/9HSZbojGaPdkC7W65Y/giphy.gif
# ************
# football GIF by SB Nation
# https://media4.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/wXQtCU1JVVVjq/giphy.gif
# ************
# Football Baby GIF by The Dude Perfect Show
# https://media1.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/3o6ozpApambvvdRMQw/giphy.gif
# ************
# Super Bowl Lol GIF by Animation Domination High-Def
# https://media1.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/YvQZtAfJ2Bpv2/giphy.gif
# ************
# Football Saintswin GIF by New Orleans Saints
# https://media4.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/j9rFe0tcNdu3f1MpdL/giphy.gif
# ************
# Team Ncaa GIF by Texas State Football
# https://media0.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/QbpX1Hbu6M3EpvIOpQ/giphy.gif
# ************
# Football Fast Motion GIF by Saweetie
# https://media0.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/ML3dt3XLf561UscdDw/giphy.gif
# ************
# Algee Smith Football GIF by euphoria
# https://media3.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/kBYeohaJsmft9mSCFT/giphy.gif
# ************
# The Beautiful Game Football GIF by World Cup
# https://media4.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/IUhgvA6bBxI98fdH1F/giphy.gif
# ************
# football GIF by SB Nation
# https://media4.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/7J096VtWdHW4E/giphy.gif
# ************
# Us Soccer Football GIF by World Cup
# https://media1.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/RQh3VCZY9qkHU9sxLu/giphy.gif
# ************
# Team Ncaa GIF by Texas State Football
# https://media2.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/JmKwmgwEXekIpJzN2M/giphy.gif
# ************
# Team Ncaa GIF by Texas State Football
# https://media4.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/zZKOZYBLrTAdWslqlj/giphy.gif
# ************
# Kicking Super Bowl GIF
# https://media4.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/FB7yASVBqPiFy/giphy.gif
# ************
# The Beautiful Game Football GIF
# https://media0.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/bb9p2vAKRE0RMSXSpq/giphy.gif
# ************
# Flag Football GIF by CLUBWAKA
# https://media2.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/s07FDtYrAoc94GmO24/giphy.gif
# ************
# Da Bears Football GIF
# https://media3.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/fXeRGki5DiU5G/giphy.gif
# ************
# air bud football GIF
# https://media0.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/g7cXuJzfODNks/giphy.gif
# ************
# Miami Dolphins Football GIF
# https://media0.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/kED33TVwtp5le/giphy.gif
# ************
# Football College GIF by Hogs+
# https://media4.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/2eBCr5ICF3OaPiGms5/giphy.gif
# ************
# Super Bowl Win GIF
# https://media2.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/S4K3XHLEJ5Zdu90CZ8/giphy.gif
# ************
# football GIF
# https://media3.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/Wpiq6wAdZw3bq/giphy.gif
# ************
# Football Celebration GIF by Hogs+
# https://media4.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/sql0PakcNFriZuOYQl/giphy.gif
# ************
# Season 5 Football GIF by Living Single
# https://media0.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/wCVqRiNMIxp9RoZym0/giphy.gif
# ************
# Team Ncaa GIF by Texas State Football
# https://media1.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/PChlfGvUl8XEevUtui/giphy.gif
# ************
# Football Fast Motion GIF by Saweetie
# https://media2.giphy.com/media/v1.Y2lkPWE0ZGRlOTdlMTl2eTZ5OGJ6eGh0cXppd2tuaXh6bzd0MGdncTcyZWwxY2JiamlzdyZlcD12MV9naWZzX3NlYXJjaCZjdD1n/Q5sjQhryb1TrinSTa1/giphy.gif
# ************
