# %%
import argparse
from pathlib import Path
from pytubefix import YouTube
from pytubefix.exceptions import VideoUnavailable
from pytubefix.cli import on_progress

# %%
url = "https://www.youtube.com/watch?v=5qF_qbaWt3Q"

yt = YouTube(url, on_progress_callback=on_progress)
print(yt.title)

ys = yt.streams.get_highest_resolution(progressive=True)
ys.download()
# Out:
# Waiting For The End (Official Music Video) [4K Upgrade] - Linkin Park
#  ↳ |████████████████████████████████████████████| 100.0%
# '/Users/majid/Documents/1. Majid Files/R Python/Python/python-projects/Level_2/1_youtube_downloader/src/Waiting For The End (Official Music Video) [4K Upgrade] - Linkin Park.mp4'
