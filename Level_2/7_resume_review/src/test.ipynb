# %%
from PyPDF2 import PdfReader


def extract_from_pdf(pdf_path):
    reader = PdfReader(pdf_path)
    resume_text = ""
    for page in reader.pages:
        text = page.extract_text()
        resume_text += text

    return resume_text

# %%
resume_text = extract_from_pdf("data/CV - Majid Zaremehrjardy.pdf")

# %%
# Try the llm_interface module
from llm_interface import call_llm
from prompts import RESUME_JSON_SCHEMA, LLM_JSON_PARSE_PROMPT, RESUME_YAML_SCHEMA, LLM_YAML_PARSE_PROMPT

prompt_json = LLM_JSON_PARSE_PROMPT.format(resume_text=resume_text, resume_schema=RESUME_JSON_SCHEMA)
response_json = call_llm(prompt_json)
print(response_json)

# %%
# Try the YAML parsing
prompt_yaml = LLM_YAML_PARSE_PROMPT.format(resume_text=resume_text, resume_schema=RESUME_YAML_SCHEMA)
response_yaml = call_llm(prompt_yaml)
print(response_yaml)
# Out:
# ```yaml
# personal_info:
#   full_name: "Majid Zaremehrjardy"
#   address:
#     street: ""
#     city: "Calgary"
#     state: "AB"
#     zip: ""
#     country: "Canada"
#   phone: "+1 780-297-9070"
#   email: "majid.zare@ualberta.ca"
#   linkedin: "ca.linkedin.com/in/mjdzr"
#   github: ""
#   website: ""
# summary: |
#   Extensive knowledge of Alberta regulations, policies and frameworks related to surface water and groundwater.
#   Experienced in building groundwater models including contaminant fate and transport models and reactive transport modeling.
#   Expert in applying statistical analysis and machine learning techniques in analyzing, reporting, and visualizing environmental pressures and risks in local and regional scales.
#   Experienced with regulatory processes related to environmental cumulative effects.
#   Professional Engineer (P.Eng) in good standing with APEGA since September 2024.
# work_experience:
#   - job_title: "Surface Water Specialist"
#     company: "Alberta Environment and Protected Areas (EPA), Planning Branch"
#     location:
#       city: "Calgary"
#       state: "AB"
#     start_date: "2021-10-01"
#     end_date: null
#     description: |
#       Leading the data collection and analysis of water quality across the Lower Athabasca and Oil Sands Monitoring (OSM) regions, bringing together 2.5 million measurements of water quality parameters.
#       Leading the development of Water Quality Dashboard and Annual Reporting Dashboard for supporting interactive representation of water quality and regulatory requirements in Alberta.
#       Supporting the development of annual water quality and management response reports for regulating surface water quality conditions in Alberta.
#       EPA representative on multi-stakeholder initiatives related to water quality such as OSM Technical Advisory Committee (OSM TAC) and various Watershed Planning and Advisory Councils (WPACs).
#     achievements:
#       - Led data collection and analysis for 2.5 million water quality measurements in OSM regions.
#       - Developed Water Quality Dashboard and Annual Reporting Dashboard.
#       - Supported development of annual water quality and management response reports.
#       - Represented EPA on OSM TAC and WPACs.
#   - job_title: "Term Lecturer"
#     company: "University of Alberta, Department of Earth and Atmospheric Sciences"
#     location:
#       city: "Edmonton"
#       state: "AB"
#     start_date: "2022-01-01"
#     end_date: null
#     description: |
#       (2023-) Geoscience Data Analysis (EAS 405/505)
#       (2022) Hydrologic modelling (EAS 456/555)
#     achievements:
#       - Instructed undergraduate and graduate courses in Geoscience Data Analysis and Hydrologic Modelling.
#   - job_title: "University Research Assistant"
#     company: "University of Alberta"
#     location:
#       city: "Edmonton"
#       state: "AB"
#     start_date: "2020-09-01"
#     end_date: "2021-10-01"
#     description: |
#       Used Hydroscape and Bioscreen models to model chloride transport and biodegradation of BTEX components and designing remediation scenarios.
#       Collaborated with Alberta Innovates Water Innovation Program (AI-WIP) and EPCOR on regional modelling of groundwater-surface water interactions in North Saskatchewan River Basin using SWAT-MODFLOW model.
#       Supervised an M. Sc. student and a B. Sc. student on groundwater modelling and drafting research articles.
#     achievements:
#       - Applied Hydroscape and Bioscreen for contaminant transport modeling.
#       - Collaborated with AI-WIP and EPCOR on major regional modelling projects.
#       - Supervised graduate and undergraduate student research.
# education:
#   - degree: "M. Sc."
#     field_of_study: "Earth and Atmospheric Sciences"
#     institution: "University of Alberta"
#     location:
#       city: "Edmonton"
#       state: "AB"
#     start_date: "2018-01-01"
#     end_date: "2020-12-31"
#     honors: []
#   - degree: "M. Sc."
#     field_of_study: "Water Resources Engineering"
#     institution: "Amirkabir University of Technology"
#     location:
#       city: ""
#       state: ""
#     start_date: "2015-01-01"
#     end_date: "2018-12-31"
#     honors: []
#   - degree: "B. Sc."
#     field_of_study: "Civil and Environmental Engineering"
#     institution: "Amirkabir University of Technology"
#     location:
#       city: ""
#       state: ""
#     start_date: "2011-01-01"
#     end_date: "2015-12-31"
#     honors: []
# skills:
#   - "Python"
#   - "R"
#   - "MATLAB"
#   - "Fortran"
#   - "LaTeX"
#   - "ArcGIS"
#   - "QGIS"
#   - "Leaflet"
#   - "HEC-GeoRAS"
#   - "ArcSWAT"
#   - "SUTRA"
#   - "MODFLOW"
#   - "HYDROSCAPE"
#   - "BIOSCREEN"
#   - "SWAT-CUP"
#   - "SWAT-MODFLOW"
#   - "HEC-HMS"
#   - "HEC-Ras"
#   - "MODSIM"
#   - "EPANET"
#   - "StormCAD"
#   - "LINGO"
#   - "SewerCAD"
#   - "QUAL2E"
#   - "Microsoft Word"
#   - "Microsoft Excel"
#   - "Microsoft Powerpoint"
# certifications:
#   - title: "Professional Engineer (P.Eng)"
#     issuer: "The Association of Professional Engineers and Geoscientists of Alberta (APEGA)"
#     date_obtained: "2021-09-01"
#     expiration_date: null
#   - title: "Principles of Hydrology"
#     issuer: "Canadian Society for Hydrological Sciences (CSHS)"
#     date_obtained: "2019-01-01"
#     expiration_date: null
#   - title: "Question, Persuade and Refer (QPR) training for suicide prevention"
#     issuer: "University of Alberta"
#     date_obtained: "2019-01-01"
#     expiration_date: null
# projects: []
# languages: []
# volunteer_experience:
#   - role: "Tutor"
#     organization: ""
#     location:
#       city: ""
#       state: ""
#     start_date: "2020-01-01"
#     end_date: "2023-12-31"
#     description: "Tutoring a student diagnosed with Autism Spectrum Disorder."
#   - role: "Certified Fire Warden and First Aider"
#     organization: ""
#     location:
#       city: "Calgary"
#       state: "AB"
#     start_date: "2023-01-01"
#     end_date: "2023-12-31"
#     description: "Worked as a Certified Fire Warden and First Aider in the South Petroleum Plaza building."
#   - role: "Teaching Assistant"
#     organization: ""
#     location:
#       city: ""
#       state: ""
#     start_date: "2017-01-01"
#     end_date: "2020-12-31"
#     description: "Teaching Assistant on Advanced Hydrological Modelling, Advanced Groundwater, and Technical English courses."
#   - role: "Charity Fundraising Group Member"
#     organization: "Students for Students non-profit organization, University of Alberta"
#     location:
#       city: "Edmonton"
#       state: "AB"
#     start_date: "2019-01-01"
#     end_date: "2019-12-31"
#     description: "Member of charity fundraising group for underprivileged students."
# interests: []
# references: []
# ```
