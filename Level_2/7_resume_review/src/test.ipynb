# %%
from PyPDF2 import PdfReader


def extract_from_pdf(pdf_path):
    reader = PdfReader(pdf_path)
    resume_text = ""
    for page in reader.pages:
        text = page.extract_text()
        resume_text += text

    return resume_text

# %%
extract_from_pdf("data/CV - Majid Zaremehrjardy.pdf")
# Out:
# 'MAJID ZAREMEHRJARDY, P.ENG\nAlberta Environment and Protected Areas, Calgary, AB\n(+1) 780-297-9070 ⋄majid.zare@ualberta.ca ⋄ca.linkedin.com/in/mjdzr\nHIGHLIGHTS\n•Extensive knowledge of Alberta regulations, policies and frameworks related to surface water and\ngroundwater.\n•Experienced in building groundwater models including contaminant fate and transport models\nand reactive transport modeling.\n•Expert in applying statistical analysis and machine learning techniques in analyzing, reporting,\nand visualizing environmental pressures and risks in local and regional scales.\n•Experienced with regulatory processes related to environmental cumulative effects.\n•Professional Engineer (P.Eng) in good standing with APEGA since September 2024.\nWORK EXPERIENCE\nSurface Water Specialist October 2021 - Present\nAlberta Environment and Protected Areas (EPA), Planning Branch\n•Leading the data collection and analysis of water quality across the Lower Athabasca and Oil\nSands Monitoring (OSM)
# ...

# %%
# Try the llm_interface module
import llm_interface
llm_interface.call_llm("Why is the sky blue?")  # Example call to the LLM interface
# Out:
# 'I can only answer questions about football.'
