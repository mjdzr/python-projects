# %% [markdown]
# - TicTacToe
# - __init__.py
# - get_random_first_player
# - mark the board based on player's move
# - swap_players
# - get_board
# - get_available_moves
# - get_winner

# %%
import numpy as np

class TicTacToe:
    def __init__(self):
        self.board = [' '] * 10

# %%
mij = TicTacToe()
mij.board
# Out:
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
